# %%
import pandas as pd

# %%
Dataurl = 'https://raw.githubusercontent.com/Datamanim/pandas/main/chipo.csv'
C_d = pd.read_csv(Dataurl, encoding = 'euc-kr')
C_d
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# C_d(['quantity'] == 3).head(5)

# [Corrected Approach]
C_d.loc[C_d['quantity'] == 3].head(5)
# Out:
#      order_id  quantity          item_name  \
# 409       178         3       Chicken Bowl
# 445       193         3               Bowl
# 689       284         3  Canned Soft Drink
# 818       338         3      Bottled Water
# 850       350         3  Canned Soft Drink
#
#                                     choice_description item_price
# 409  [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...    $32.94
# 445  [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20
# 689                                        [Diet Coke]     $3.75
# 818                                                NaN     $3.27
# 850                                           [Sprite]     $3.75

# %%
# 만약 본사에 보고해야하는데 index number 409 , 445를 reset

C_d.loc[C_d['quantity'] == 3].head(5).reset_index(drop = True)
# Out:
#    order_id  quantity          item_name  \
# 0       178         3       Chicken Bowl
# 1       193         3               Bowl
# 2       284         3  Canned Soft Drink
# 3       338         3      Bottled Water
# 4       350         3  Canned Soft Drink
#
#                                   choice_description item_price
# 0  [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...    $32.94
# 1  [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20
# 2                                        [Diet Coke]     $3.75
# 3                                                NaN     $3.27
# 4                                           [Sprite]     $3.75

# %%
C_d.loc[C_d['quantity'] == 3].head(5).reset_index(drop = False)

# 기존의 index를 살림
# Out:
#    index  order_id  quantity          item_name  \
# 0    409       178         3       Chicken Bowl
# 1    445       193         3               Bowl
# 2    689       284         3  Canned Soft Drink
# 3    818       338         3      Bottled Water
# 4    850       350         3  Canned Soft Drink
#
#                                   choice_description item_price
# 0  [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...    $32.94
# 1  [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20
# 2                                        [Diet Coke]     $3.75
# 3                                                NaN     $3.27
# 4                                           [Sprite]     $3.75

# %%
# Quantity and item_price

a  = C_d[['quantity', 'item_price']]
a
# Out:
#       quantity item_price
# 0            1     $2.39
# 1            1     $3.39
# 2            1     $3.39
# 3            1     $2.39
# 4            2    $16.98
# ...        ...        ...
# 4617         1    $11.75
# 4618         1    $11.75
# 4619         1    $11.25
# 4620         1     $8.75
# 4621         1     $8.75
#
# [4622 rows x 2 columns]

# %%
C_d
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# $제거 , float type으로 변경, new_price column 새로 생성 및 저장
C_d['Adjusted_Price'] = C_d['item_price'].str[1:].astype('float')
Adjusted_Price = C_d['Adjusted_Price'].head()
Adjusted_Price
# Out:
# 0     2.39
# 1     3.39
# 2     3.39
# 3     2.39
# 4    16.98
# Name: Adjusted_Price, dtype: float64

# %%
C_d
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 0                                                   NaN     $2.39
# ...

# %%
# Adjusted_Price에서 5.00 이하인 값을 가지는 데이터 프레임 추출

# %%
C_d
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 0                                                   NaN     $2.39
# ...

# %%
#Adjusted_Price[(Adjusted_Price <= 5.00)].count()
b = len(C_d.loc[C_d.Adjusted_Price <= 5.00])
b
# Out:
# 1652

# %%
# item_name == 'Chicken Salad Bowl 추출, index 값을 초기화
c = C_d.loc[C_d.item_name == 'Chicken Salad Bowl'].reset_index(drop = True).head(8)
c
# Out:
#    order_id  quantity           item_name  \
# 0        20         1  Chicken Salad Bowl
# 1        60         2  Chicken Salad Bowl
# 2        94         2  Chicken Salad Bowl
# 3       111         1  Chicken Salad Bowl
# 4       137         2  Chicken Salad Bowl
# 5       220         1  Chicken Salad Bowl
# 6       221         1  Chicken Salad Bowl
# 7       221         1  Chicken Salad Bowl
#
#                                   choice_description item_price  \
# 0  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
# 1  [Tomatillo Green Chili Salsa, [Sour Cream, Che...    $22.50
# 2  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $22.50
# 3  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $8.75
# 4            [Fresh Tomato Salsa, Fajita Vegetables]    $17.50
# 5  [Roasted Chili Corn Salsa, [Black Beans, Sour ...     $8.75
# 6  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...     $8.75
# 7  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...     $8.75
#
# ...

# %%
d =  C_d.loc[(C_d.item_name == 'Chicken Salad Bowl') & (C_d.Adjusted_Price <= 10.00)].reset_index(drop = True)
d
# Out:
#     order_id  quantity           item_name  \
# 0         20         1  Chicken Salad Bowl
# 1        111         1  Chicken Salad Bowl
# 2        220         1  Chicken Salad Bowl
# 3        221         1  Chicken Salad Bowl
# 4        221         1  Chicken Salad Bowl
# 5        234         1  Chicken Salad Bowl
# 6        240         1  Chicken Salad Bowl
# 7        286         1  Chicken Salad Bowl
# 8        289         1  Chicken Salad Bowl
# 9        314         1  Chicken Salad Bowl
# 10       458         1  Chicken Salad Bowl
# 11       592         1  Chicken Salad Bowl
# 12       598         1  Chicken Salad Bowl
# 13       602         1  Chicken Salad Bowl
# 14       628         1  Chicken Salad Bowl
# 15       649         1  Chicken Salad Bowl
# 16       654         1  Chicken Salad Bowl
# 17       709         1  Chicken Salad Bowl
# 18       798         1  Chicken Salad Bowl
# 19       818         1  Chicken Salad Bowl
# 20       850         1  Chicken Salad Bowl
# ...

# %%
e = C_d.sort_values('Adjusted_Price').reset_index(drop = True)
e.tail(3)
# Out:
#       order_id  quantity                     item_name  \
# 4619       511         4               Chicken Burrito
# 4620      1398         3                 Carnitas Bowl
# 4621      1443        15  Chips and Fresh Tomato Salsa
#
#                                      choice_description item_price  \
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $35.00
# 4620  [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $35.25
# 4621                                                NaN    $44.25
#
#       Adjusted_Price
# 4619           35.00
# 4620           35.25
# 4621           44.25

# %%
#C_d의 item_name에서 메뉴 이름에 'Chips'가 들어가는 데이터
f = C_d.loc[C_d.item_name.str.contains('Chips')]
f.head(6)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 6          3         1                          Side of Chips
# 10         5         1                    Chips and Guacamole
# 14         7         1                    Chips and Guacamole
# 15         8         1  Chips and Tomatillo-Green Chili Salsa
#
#    choice_description item_price  Adjusted_Price
# 0                 NaN     $2.39             2.39
# 3                 NaN     $2.39             2.39
# 6                 NaN     $1.69             1.69
# 10                NaN     $4.45             4.45
# 14                NaN     $4.45             4.45
# 15                NaN     $2.39             2.39

# %%
# Adjusted_Priced의 칼럼값들을 내림차순, index 초기화
g = C_d.sort_values('Adjusted_Price',ascending= False).reset_index(drop=True)
g.head(3)
# Out:
#    order_id  quantity                     item_name  \
# 0      1443        15  Chips and Fresh Tomato Salsa
# 1      1398         3                 Carnitas Bowl
# 2       511         4               Chicken Burrito
#
#                                   choice_description item_price  \
# 0                                                NaN    $44.25
# 1  [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $35.25
# 2  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $35.00
#
#    Adjusted_Price
# 0           44.25
# 1           35.25
# 2           35.00

# %%
# item name 컬럼값이 steak salad 또는 bowl인 데이터 출력
# h = C_d.loc[(C_d.item_name.str.contains('Steak Salad')) | (C_d.item_name.str.contains('Bowl'))]
# h

h = C_d.loc[(C_d.item_name == 'Steak Salad') | (C_d.item_name == 'Bowl')]
h
# Out:
#       order_id  quantity    item_name  \
# 445        193         3         Bowl
# 664        276         1  Steak Salad
# 673        279         1         Bowl
# 752        311         1  Steak Salad
# 893        369         1  Steak Salad
# 3502      1406         1  Steak Salad
#
#                                      choice_description item_price  \
# 445   [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20
# 664   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     $8.99
# 673   [Adobo-Marinated and Grilled Steak, [Sour Crea...     $7.40
# 752   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     $8.99
# 893   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...     $8.99
# 3502                        [[Lettuce, Fajita Veggies]]     $8.69
#
#       Adjusted_Price
# 445            22.20
# 664             8.99
# 673             7.40
# 752             8.99
# 893             8.99
# 3502            8.69

# %%
# 중복된 부분 drop

i =  C_d.loc[(C_d.item_name == 'Steak Salad') | (C_d.item_name == 'Bowl')]
i = i.drop_duplicates('item_name',keep='last')
i
# Out:
#       order_id  quantity    item_name  \
# 673        279         1         Bowl
# 3502      1406         1  Steak Salad
#
#                                      choice_description item_price  \
# 673   [Adobo-Marinated and Grilled Steak, [Sour Crea...     $7.40
# 3502                        [[Lettuce, Fajita Veggies]]     $8.69
#
#       Adjusted_Price
# 673             7.40
# 3502            8.69

# %%
#C_d의 new_price값이 new_price의 평균값 이상을 가지는 데이터 추출
j = C_d.loc[C_d.Adjusted_Price >= Adjusted_Price.mean()]
j.head(5)
# Out:
#    order_id  quantity         item_name  \
# 4         2         2      Chicken Bowl
# 5         3         1      Chicken Bowl
# 7         4         1     Steak Burrito
# 8         4         1  Steak Soft Tacos
# 9         5         1     Steak Burrito
#
#                                   choice_description item_price  \
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25
#
#    Adjusted_Price
# 4           16.98
# 5           10.98
# 7           11.75
# 8            9.25
# 9            9.25

# %%
#C_d의 choice_description 값이 NaN인 데이터의 수

k = C_d.choice_description.isnull().sum()
k
# Out:
# 1246

# %%
# NaN인 데이터를 'No Data'로 대체
l = C_d.loc[C_d.choice_description.isnull(),'choice_description'] = 'No Data'

# C_d에 업데이트
l = C_d
l.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  \
# 0                                            No Data     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                            No Data     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
#
#    Adjusted_Price
# 0            2.39
# 1            3.39
# 2            3.39
# 3            2.39
# 4           16.98

# %%
# choice_description에 Black이 들어가는 경우
m = C_d[(C_d.choice_description.str.contains('Black'))]
m
# Out:
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 7            4         1         Steak Burrito
# 9            5         1         Steak Burrito
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# ...        ...       ...                   ...
# 4604      1828         1          Chicken Bowl
# 4608      1829         1        Veggie Burrito
# 4611      1830         1        Veggie Burrito
# 4612      1831         1         Carnitas Bowl
# 4617      1833         1         Steak Burrito
#
#                                      choice_description item_price  \
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25
# 11    [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75
# ...

# %%
#choice_description에서 vegetables가 들어가는 경우 데이터 숫자

o = len(C_d[~ C_d.choice_description.str.contains('Vegetables')])
o
# Out:
# 3900

# %%
# Item의 Value가 'N'으로 시작하는 경우
p = C_d[C_d.item_name.str.startswith('N')]
p.head(4)
# Out:
#      order_id  quantity         item_name         choice_description  \
# 2           1         1  Nantucket Nectar                    [Apple]
# 22         11         1  Nantucket Nectar       [Pomegranate Cherry]
# 105        46         1  Nantucket Nectar  [Pineapple Orange Banana]
# 173        77         1  Nantucket Nectar                    [Apple]
#
#     item_price  Adjusted_Price
# 2       $3.39             3.39
# 22      $3.39             3.39
# 105     $3.39             3.39
# 173     $3.39             3.39

# %%
# item_name의 value가 15글자 이상
q = C_d[C_d.item_name.str.len() >= 15]
q.head
# Out:
# <bound method NDFrame.head of       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 8            4         1                       Steak Soft Tacos
# 10           5         1                    Chips and Guacamole
# ...        ...       ...                                    ...
# 4615      1832         1                     Chicken Soft Tacos
# 4616      1832         1                    Chips and Guacamole
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 0                                               No Data     $2.39
# ...
