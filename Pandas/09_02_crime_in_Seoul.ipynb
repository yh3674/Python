# %%
import pandas as pd
import matplotlib.pyplot as plt
import squarify

# %%
seoul_Data = pd.read_csv("crime_in_Seoul.csv", index_col = '관서명' , encoding ='euc-kr') 
seoul_Data.head(4)
# Out:
#       살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생 절도 검거  폭력 발생  폭력 검거
# 관서명
# 중부서       2      2      3      2    105     65  1,395   477  1,355  1,170
# 종로서       3      3      6      5    115     98  1,070   413  1,278  1,070
# 남대문서      1      0      6      4     65     46  1,153   382    869    794
# 서대문서      2      2      5      4    154    124  1,812   738  2,056  1,711

# %%
# 각 열들 끼리 correlation?

seoul_Data.corr() # positive // negative
# Out:
#           살인 발생     살인 검거     강도 발생     강도 검거     강간 발생     강간 검거
# 살인 발생  1.000000  0.953920  0.640281  0.486899  0.621728  0.572858
# 살인 검거  0.953920  1.000000  0.648964  0.505346  0.575409  0.571278
# 강도 발생  0.640281  0.648964  1.000000  0.866390  0.745120  0.798568
# 강도 검거  0.486899  0.505346  0.866390  1.000000  0.604698  0.744171
# 강간 발생  0.621728  0.575409  0.745120  0.604698  1.000000  0.915617
# 강간 검거  0.572858  0.571278  0.798568  0.744171  0.915617  1.000000

# %%
seoul_Data[['살인 발생','살인 검거']]
# Out:
#       살인 발생  살인 검거
# 관서명
# 중부서       2      2
# 종로서       3      3
# 남대문서      1      0
# 서대문서      2      2
# 혜화서       3      2
# 용산서       5      5
# 성북서       2      2
# 동대문서      5      5
# 마포서       8      8
# 영등포서     14     12
# 성동서       4      4
# 동작서       5      5
# 광진서       4      4
# 서부서       2      2
# 강북서       7      8
# 금천서       3      4
# 중랑서      13     12
# 강남서       3      3
# 관악서       9      8
# 강서서       7      8
# 강동서       4      3
# 종암서       3      3
# 구로서       8      6
# 서초서       7      4
# 양천서       3      5
# 송파서      11     10
# 노원서      10     10
# 방배서       1      2
# 은평서       1      1
# 도봉서       3      3
# 수서서      10      7

# %%
seoul_Data.plot(kind = 'scatter', x= '살인 발생', y = '살인 검거')
plt.show()
# Out:
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49332 (\N{HANGUL SYLLABLE SAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48156 (\N{HANGUL SYLLABLE BAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49373 (\N{HANGUL SYLLABLE SAENG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44160 (\N{HANGUL SYLLABLE GEOM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
